# %%
def even(num):
    if num%2==0:
        return True

even(24)
# Out:
# True

# %%
lst=[1,2,3,4,4,5,6,7,8,9]
list(filter(even,lst))
# Out:
# [2, 4, 4, 6, 8]

# %%
print(lst)
# Out:
# [1, 2, 3, 4, 4, 5, 6, 7, 8, 9]

# %%
greater_than_three=list(filter(lambda x:x>3 and x%2==0,lst))

print(greater_than_three)
# Out:
# [4, 4, 6, 8]
