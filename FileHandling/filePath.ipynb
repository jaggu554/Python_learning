# %%
import os
pwd=os.getcwd()
print(pwd)
# Out:
# /Users/jagadeeswarreddyvankala/Documents/PYTHON/FileHandling

# %%
# package=os.mkdir("package")
lst=os.listdir('.')
print(lst)
# Out:
# ['fileoperation.ipynb', 'destination.txt', 'filePath.ipynb', 'example.bin', 'example.txt', 'package']

# %%
dir_name="folder"
file_name="file.txt"

os.path.join(os.getcwd(),dir_name,file_name)
# Out:
# '/Users/jagadeeswarreddyvankala/Documents/PYTHON/FileHandling/folder/file.txt'
