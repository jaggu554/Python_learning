# %%
with open('example.txt','r') as file:
    content=file.read()
    print(content)
# Out:
# This is a newLine
# This is the comments written

# %%
#writing a file overwrites old content

with open('example.txt','w') as file:
    file.write("This is a newLine \n")
    file.write("This is the comments written \n")

with open('example.txt','r') as file:
    for line in file:
        print(line.strip())
# Out:
# This is a newLine
# This is the comments written

# %%
with open('example.txt','a') as file:
    file.writelines("\n This is Jagadeeswar Redddy Vankala \nStarted Learning File Handling \nThis is the resume Example")

# %%
with open('example.txt','r') as file:
    for line in file:
        print(line.strip())
# Out:
# This is Jagadeeswar Redddy Vankala
# Started Learning File Handling
# This is the resume Example

# %%
lines=["This is a line \n This is a process \n This is the KingJaggu"]
with open('example.txt','a') as file:
    file.writelines(lines)

# %%
data = b'\x00\x01\x02\x03\x04'

with open("example.bin",'wb') as file:
    file.write(data)

# %%
with open('example.bin','rb') as file:
    content=file.read()
    print(content)
# Out:
# b'\x00\x01\x02\x03\x04'

# %%
with open('example.txt','r') as source_file:
    content=source_file.read()
    print(content)

with open('destination.txt','w') as destination_file:
    destination_file.write(content)
# Out:
#  This is Jagadeeswar Redddy Vankala
# Started Learning File Handling
# This is the resume ExampleThis is a line
#  This is a process
#  This is the KingJagguThis is a line
#  This is a process
#  This is the KingJaggu

# %%
def count_text_file(file_path):
    with open(file_path,'r') as file:
      lines = file.readlines()
      line_count=len(lines)
      word_count=sum(len(line.split()) for line in lines)
      char_count=sum(len(line) for line in lines)
    return line_count,word_count,char_count

count_text_file("example.txt")
# Out:
# (8, 36, 212)
