# %%
class Animal:
    def speak(self):
        return "Animal is barking"
    
class Dog(Animal):
    def speak(self):
        return "Dog is barking"
    
class BabyDog(Animal):
    def speak(self):
        return "BabyDog is barking"

def animal_speak(animal):
    return animal.speak()

b=Dog()
print(b.speak());  
print(animal_speak(b))

c=BabyDog()
print(animal_speak(c))


a=Animal()
print(animal_speak(a))
# Out:
# Dog is barking
# Dog is barking
# BabyDog is barking
# Animal is barking

# %%
class Shape:
    def area(self):
        print("Printing Area of shape")

class Rectangle(Shape):
    def __init__(self,width,breadth):
        self.width=width
        self.breadth=breadth

    def area(self):
        return self.width*self.breadth

class Circle(Shape):
    def __init__(self,radius):
        self.radius=radius

    def area(self):
        return 3.14*self.radius*self.radius
    

def print_area(shape):
    print(shape.area())

r=Rectangle(5,4)
print_area(r)

c=Circle(6)
print_area(c)
# Out:
# 20
# 113.03999999999999

# %%
from abc import ABC,abstractmethod

class Vehicle(ABC):
    @abstractmethod
    def start_engine(self):
        pass

class Car(Vehicle):
    def start_engine(self):
        return "car is parking..."
    
class Bike(Vehicle):
    def start_engine(self):
        return "bike is parking..."
    
def print_start_engine(vehicle):
    print(vehicle.start_engine())

v=Car()
print_start_engine(v)

b=Bike()
print_start_engine(b)
# Out:
# car is parking...
# bike is parking...
