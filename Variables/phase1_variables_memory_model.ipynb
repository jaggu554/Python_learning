# %%
list1=[1,2,3,4,4,5,6,7]

list2=list1.copy()

list1.append(100)
print(id(list1))
print(id(list2))

print(list1)
print(list2)
# Out:
# 4405668160
# 4405642560
# [1, 2, 3, 4, 4, 5, 6, 7, 100]
# [1, 2, 3, 4, 4, 5, 6, 7]
