# %%
import math
result=math.sqrt(64)

print(result)
# Out:
# 8.0

# %%
import math 
pow =math.pow(2,4)
print(pow)
# Out:
# 16.0

# %%
import math
lcm=math.lcm(45)
print(lcm)
# Out:
# 45

# %%
from math import pi,sqrt
print(math.sqrt(81))
print(math.pi)
# Out:
# 9.0
# 3.141592653589793

# %%
import numpy as np
np.array([1,2,3,4,5])
# Out:
# array([1, 2, 3, 4, 5])

# %%
from package.maths import addition

add=addition(2,3)
print(add)
# Out:
# 5

# %%
from package.maths import subraction
sub=subraction(4,5)
print(sub)
# Out:
# -1

# %%
from package.subpackages.multi import *
prod=multi(10,20)
print(prod)
# Out:
# 200

# %%
from package.subpackages.multi import *
multi(200,100)
# Out:
# 20000

# %%
from package.subpackages.multi import *
pow(100,20)
# Out:
# 10000000000000000000000000000000000000000
